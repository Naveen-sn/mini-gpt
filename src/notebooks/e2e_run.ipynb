# %%
# %cd /Users/garima/Documents/Naveen/learning/workspace/oss-chatbot
# Out:
# /Users/garima/Documents/Naveen/learning/workspace/oss-chatbot

# %% [markdown]
# raw data

# %%
from src.module.data import tiny_shakespeare
raw_text = tiny_shakespeare.DATA

# %% [markdown]
# convert raw data to tokens and tensor

# %%
from src.module.tokenization import tasks
data = tasks.encode(raw_text)
# Out:
# tensor([ 7127, 84479,   734,  ...,  1957, 78034,   558])

# %% [markdown]
# test train split

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, val_data = train_test_split(data, test_size=0.1)
# Out:
# torch.Size([297606]) torch.Size([267845]) torch.Size([29761])
